# %% [markdown]
# # Assembly de Novo
#
# This workflow page is prepared as supplementary code for Shotgun Metagenomic Analysis in Pediatric With Acute Diarrhea

# %% [markdown]
# # Assembly de Novo using Megahit
# Megahit Installation and code source (https://github.com/voutcn/megahit)

# %%
megahit -1 File_1_kneaddata_paired_1.fastq -2 File_1_kneaddata_paired_2.fastq -o File_1 --mem-flag 1 -t 10 -m 0.7 &

# %% [markdown]
# # Evaluating Contigs Using Quast
# Quast installation and code source (https://github.com/ablab/quast)

# %%
./quast.py contigs_1.fasta \
           contigs_2.fasta \
 -r reference.fasta.gz \
 -g genes.txt \
 -1 reads1.fastq.gz -2 reads2.fastq.gz \
 -o quast_test_output

# %% [markdown]
# # Example Results of QUAST Contigs Evaluation
#
# <img src="img/Quast_contigs_evaluation.png"/>
#
# <center> Inspect the contigs quality (N50 and L50)</center>
