# %% [markdown]
# # Antimicrobial Resistance, Sequence Ty[ing, Virulence Factor
#
# This workflow page is prepared as supplementary code for Shotgun Metagenomic Analysis in Pediatric With Acute Diarrhea

# %% [markdown]
# # Multiple Sequence Alignment (MSA) using MAFFT
# Mafft online website (https://www.ebi.ac.uk/jdispatcher/msa/mafft?stype=dna) or you can download and install Mafft from https://github.com/GSLBiotech/mafft

# %%
mafft input.fasta > output.fasta

# %% [markdown]
# # Virulence Factor of Pathogenic Bacteria and Sequence Typing
# Mass screening of contigs for antimicrobial resistance or virulence genes using Abricate (https://github.com/tseemann/abricate). Virulence Finder using VFanalyzer (https://www.mgc.ac.cn/cgi-bin/VFs/v5/main.cgi?func=VFanalyzer). Sequence Typing using MLST (https://cge.food.dtu.dk/services/MLST/)

# %%
abricate assembly.fa

# %% [markdown]
# # Example Results of MLST
#
# <img src="img/MLST_result.png"/>
#
# <center> MLST Escherichia coli ST 648</center>
