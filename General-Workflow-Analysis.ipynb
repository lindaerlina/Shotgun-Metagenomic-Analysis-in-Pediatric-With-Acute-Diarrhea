# %% [markdown]
# # Shotgun Metagenomic Analysis in Pediatric With Acute Diarrhea
#
# This workflow page is prepared as supplementary code for Shotgun Metagenomic Analysis in Pediatric With Acute Diarrhea
#
# ## Tutorial sections
# This tutorial comprises the following sections:
#  1. [Quality control and Trimming](2_QC_Trimming.ipynb)
#  2. [Assembly de Novo](3_Assembly_denovo.ipynb)
#  3. [Antimicrobial Resistance Genes](4_Antimicrobial_resistance.ipynb)
#  4. [Taxonomy Analysis](5_Taxonomy_Analysis.ipynb)
#  5. [Microbial Pathway, Beta Diversity and Index Dysbiosis](6_HumanN2_Beta_Dysbiosis_Analysis.ipynb)

# %% [markdown]
# # Introduction
# FASTQ Data soon can be accessed in SRA NCBI (Submission ID: SUB15945629) --> recent status: uploading the files in progress.

# %% [markdown]
# # General Workflow of Shotgun Sequencing and Bioinformatics Analysis
#
# <img src="img/general_workflow.png"/>
#
# <center> General Workflow for the study including DNA Extraction, Library Preparation, Sequencing and Shotgun Metagenomic Analysis </center>
